# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV

# %%
def rmse(predictor,target):
    return np.sqrt(((predictor - target) ** 2).mean())

# %%
df = pd.read_csv('../data/train.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
#Check for any null values
df.isna().any()
# Out:
# User_ID                       False
# Product_ID                    False
# Gender                        False
# Age                           False
# Occupation                    False
# City_Category                 False
# Stay_In_Current_City_Years    False
# Marital_Status                False
# Product_Category_1            False
# Product_Category_2             True
# Product_Category_3             True
# Purchase                      False
# dtype: bool

# %%
#Fill the null values with 0

df.fillna(0, inplace= True)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0      8370
# 1                 6.0                14.0     15200
# 2                 0.0                 0.0      1422
# 3                14.0                 0.0      1057
# 4                 0.0                 0.0      7969

# %%
df = df.astype({'Product_Category_2': int, 'Product_Category_3': int})

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                   0                   0      8370
# 1                   6                  14     15200
# 2                   0                   0      1422
# 3                  14                   0      1057
# 4                   0                   0      7969

# %%
#Mapping gender values
gender = {'F':0, 'M':1}

df['Gender'] = df['Gender'].map(gender)
df = df.rename(columns={'Gender': 'isMale'})

# %%
df.head()
# Out:
#    User_ID Product_ID  isMale   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                   0                   0      8370
# 1                   6                  14     15200
# 2                   0                   0      1422
# 3                  14                   0      1057
# 4                   0                   0      7969

# %%
df.sort_values('Age', inplace=True)
df.head()
# Out:
#        User_ID Product_ID  isMale   Age  Occupation City_Category  \
# 0      1000001  P00069042       0  0-17          10             A
# 48932  1001499  P00100442       1  0-17          10             C
# 48933  1001499  P00255842       1  0-17          10             C
# 48934  1001499  P00070342       1  0-17          10             C
# 48935  1001499  P00275542       1  0-17          10             C
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2               0                   3
# 48932                          1               0                   2
# 48933                          1               0                  16
# 48934                          1               0                   1
# 48935                          1               0                   1
#
#        Product_Category_2  Product_Category_3  Purchase
# 0                       0                   0      8370
# 48932                   4                   5     13129
# 48933                   0                   0     20195
# 48934                   2                  14     15819
# 48935                   0                   0      7587

# %%
df['Age'] = df['Age'].factorize()[0]

# %%
df.tail()
# Out:
#         User_ID Product_ID  isMale  Age  Occupation City_Category  \
# 47161   1001252  P00357242       1    6          13             C
# 47162   1001252  P00322942       1    6          13             C
# 114629  1005686  P00101942       1    6          16             A
# 188070  1005033  P00112342       0    6          13             C
# 132077  1002280  P00004142       1    6           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 47161                           3               0                   5
# 47162                           3               0                   2
# 114629                          1               1                   8
# 188070                          1               1                  13
# 132077                          2               1                   8
#
#         Product_Category_2  Product_Category_3  Purchase
# 47161                    0                   0      7134
# 47162                    8                  16     16325
# 114629                  17                   0      4056
# 188070                  16                   0       936
# 132077                  17                   0      7900

# %% [markdown]
# Mapping Age column to dummy values:
#
# 0-17: 0<br>
# 18-25: 1<br>
# 26-35: 2<br>
# 36-45: 3<br>
#
# 46-50: 4
#
# 51-55: 5
#
# 55+ : 6

# %%
city = {'A': 1, 'B': 2, 'C':3}

df['City_Category'] = df['City_Category'].map(city)

df.head()
# Out:
#        User_ID Product_ID  isMale  Age  Occupation  City_Category  \
# 0      1000001  P00069042       0    0          10              1
# 48932  1001499  P00100442       1    0          10              3
# 48933  1001499  P00255842       1    0          10              3
# 48934  1001499  P00070342       1    0          10              3
# 48935  1001499  P00275542       1    0          10              3
#
#       Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2               0                   3
# 48932                          1               0                   2
# 48933                          1               0                  16
# 48934                          1               0                   1
# 48935                          1               0                   1
#
#        Product_Category_2  Product_Category_3  Purchase
# 0                       0                   0      8370
# 48932                   4                   5     13129
# 48933                   0                   0     20195
# 48934                   2                  14     15819
# 48935                   0                   0      7587

# %%
df['Stay_In_Current_City_Years'].replace({'4+':4}, inplace=True)

# %%
df['Product_ID'] = df['Product_ID'].str[1:] # Drop the first character ‘P’ from product id
df = df.astype({'Product_ID':int,'Stay_In_Current_City_Years':int}) # Recast all strings as ints

# %%
train, test = train_test_split(df,test_size=0.3)

# %%
X = train.drop('Purchase',axis=1)
y = train.Purchase

# %%
np.asarray(X)
# Out:
# array([[1001356,  136542,       0, ...,       5,       8,       0],
#        [1001135,   19342,       1, ...,       1,       6,      15],
#        [1003615,  200642,       1, ...,      10,      16,       0],
#        ...,
#        [1004502,  154242,       1, ...,       8,       0,       0],
#        [1003964,  101342,       1, ...,       6,       8,       0],
#        [1000509,  216342,       1, ...,       3,       4,       5]])

# %%
multivar_model = sm.OLS(y,sm.add_constant(X)).fit()

# %%
multivar_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Purchase   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     6403.
# Date:                Fri, 30 Nov 2018   Prob (F-statistic):               0.00
# Time:                        11:32:48   Log-Likelihood:            -3.7952e+06
# No. Observations:              385047   AIC:                         7.590e+06
# Df Residuals:                  385035   BIC:                         7.591e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -1507.1581   4332.510     -0.348      0.728   -9998.748    6984.432
# User_ID                        0.0112      0.004      2.582      0.010       0.003       0.020
# Product_ID                    -0.0028   7.35e-05    -38.169      0.000      -0.003      -0.003
# isMale                       486.4931     17.414     27.937      0.000     452.362     520.624
# Age                          108.4523      5.870     18.477      0.000      96.948     119.957
# Occupation                     6.3610      1.154      5.510      0.000       4.098       8.624
# City_Category                323.0166      9.873     32.717      0.000     303.666     342.367
# Stay_In_Current_City_Years    10.5321      5.780      1.822      0.068      -0.797      21.861
# Marital_Status               -36.8887     15.930     -2.316      0.021     -68.111      -5.666
# Product_Category_1          -344.2666      2.056   -167.457      0.000    -348.296    -340.237
# Product_Category_2             8.6084      1.207      7.133      0.000       6.243      10.974
# Product_Category_3           137.5986      1.303    105.637      0.000     135.046     140.152
# ==============================================================================
# Omnibus:                    39141.920   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54032.914
# Skew:                           0.822   Prob(JB):                         0.00
# Kurtosis:                       3.817   Cond. No.                     5.93e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.93e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Sta_In_Current_City_Years has a p-value >= 0.05, so it will be dropped.

# %%
X = train.drop(columns=['Purchase','Stay_In_Current_City_Years'],axis=1)
X.head()
# Out:
#         User_ID  Product_ID  isMale  Age  Occupation  City_Category  \
# 48002   1001356      136542       0    1           4              2
# 318701  1001135       19342       1    5          13              3
# 23108   1003615      200642       1    2          17              3
# 428149  1005917      193642       0    5           1              1
# 319234  1001202      196042       1    3          12              2
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 48002                0                   5                   8
# 318701               1                   1                   6
# 23108                0                  10                  16
# 428149               1                   2                   3
# 319234               0                   4                   9
#
#         Product_Category_3
# 48002                    0
# 318701                  15
# 23108                    0
# 428149                   4
# 319234                  15

# %%
multivar_model = sm.OLS(y,sm.add_constant(X)).fit()
multivar_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Purchase   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     7043.
# Date:                Fri, 30 Nov 2018   Prob (F-statistic):               0.00
# Time:                        11:32:48   Log-Likelihood:            -3.7952e+06
# No. Observations:              385047   AIC:                         7.590e+06
# Df Residuals:                  385036   BIC:                         7.591e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -1257.3787   4330.354     -0.290      0.772   -9744.743    7229.985
# User_ID                0.0109      0.004      2.529      0.011       0.002       0.019
# Product_ID            -0.0028   7.35e-05    -38.173      0.000      -0.003      -0.003
# isMale               486.7991     17.413     27.956      0.000     452.669     520.929
# Age                  108.3962      5.870     18.467      0.000      96.892     119.900
# Occupation             6.4200      1.154      5.563      0.000       4.158       8.682
# City_Category        323.3662      9.871     32.759      0.000     304.019     342.713
# Marital_Status       -37.2052     15.929     -2.336      0.020     -68.426      -5.985
# Product_Category_1  -344.2735      2.056   -167.460      0.000    -348.303    -340.244
# Product_Category_2     8.6124      1.207      7.136      0.000       6.247      10.978
# Product_Category_3   137.6000      1.303    105.638      0.000     135.047     140.153
# ==============================================================================
# Omnibus:                    39139.843   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54029.148
# Skew:                           0.822   Prob(JB):                         0.00
# Kurtosis:                       3.817   Cond. No.                     5.93e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.93e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Human behavior is imprecise, so a lower R-squared may be OK so long as the independent variables are significant.

# %%
tempSlice = train.sample(n=10000) # Using a small slice to run a pairplot on - should give us an accurate idea of any relations while being efficient
sns.pairplot(tempSlice)

# %% [markdown]
# There appear to be relationships between the product categories.

# %%
prediction = multivar_model.predict(sm.add_constant(test.drop(columns=['Purchase','Stay_In_Current_City_Years'],axis=1)))

# %%
rmse(prediction,test['Purchase'])
# Out:
# 4615.249094805387

# %% [markdown]
# Testing simple, single-var models

# %%
for c in df.columns:
    if (c == 'Purchase' or c == 'Stay_In_Current_City_Years'): continue
    X = train[c]
    y = train.Purchase
    model = sm.OLS(y,sm.add_constant(X)).fit()
    print(c)
    print('Adjusted R-Squared: '+str(model.rsquared_adj))
    prediction = model.predict(sm.add_constant(test[c]))
    print('RMSE: '+str(rmse(prediction,test['Purchase'])))
    print('\n')
# Out:
# User_ID
# Adjusted R-Squared: 1.9914130280351827e-05
# RMSE: 5025.665091635307
#
#
# Product_ID
# Adjusted R-Squared: 0.01106164244531771
# RMSE: 5000.006650375168
#
#
# isMale
# Adjusted R-Squared: 0.003521640770880241
# RMSE: 5015.880152252632
#
#
# Age
# Adjusted R-Squared: 0.00024444483154006935
# RMSE: 5025.066666036637
#
#
# Occupation
# Adjusted R-Squared: 0.0004548884549377963
# RMSE: 5024.768630923539
#
#
# City_Category
# Adjusted R-Squared: 0.003842446387141596
# RMSE: 5016.145865632958
#
#
# Marital_Status
# Adjusted R-Squared: -2.0875625987848423e-06
# RMSE: 5025.732140089273
#
#
# Product_Category_1
# Adjusted R-Squared: 0.11753886858634033
# RMSE: 4715.872139436587
#
#
# Product_Category_2
# Adjusted R-Squared: 0.002685914151948965
# RMSE: 5018.57953107764
#
#
# Product_Category_3
# Adjusted R-Squared: 0.08281834193935245
# RMSE: 4809.513757370277

# %% [markdown]
# Simple models do not beat the basic multivariate model on RMSE.

# %% [markdown]
# Testing individual parameter transformations in a multivariate model.

# %%
df.User_ID.eq(0).any()
# Out:
# False

# %%
for c in df.columns:
    if (c == 'Purchase' or c == 'Stay_In_Current_City_Years'): continue
    print(c)
    for t in ['square','sqrt','log']:
        loopDf = df.copy()
        if t == 'square': loopDf[c+'_'+t] = loopDf[c]**2
        elif t == 'sqrt': loopDf[c+'_'+t] = np.sqrt(loopDf[c])
        elif t == 'log': 
            if loopDf[c].eq(0).any() == True: #np.log will throw a divide by 0 error if 0 exists
                print('0 in '+c+', skipping')
                continue
            else: loopDf[c+'_'+t] = np.log(loopDf[c])
        loopDf.drop(c,axis=1,inplace=True)
        loopTrain, loopTest = train_test_split(loopDf,test_size=0.3)
        X = loopTrain.drop(['Purchase','Stay_In_Current_City_Years'],axis=1)
        y = loopTrain.Purchase
        model = sm.OLS(y,sm.add_constant(X)).fit()
        print(t)
        print('Adjusted R-Squared: '+str(model.rsquared_adj))
        prediction = model.predict(sm.add_constant(loopTest.drop(['Purchase', 'Stay_In_Current_City_Years'],axis=1)))
        print('RMSE: '+str(rmse(prediction,loopTest['Purchase'])))
    print('\n')
# Out:
# User_ID
# square
# Adjusted R-Squared: 0.15488025255439763
# RMSE: 4616.073886817266
# sqrt
# Adjusted R-Squared: 0.15432463763614013
# RMSE: 4615.654147958031
# log
# Adjusted R-Squared: 0.15410730044184062
# RMSE: 4606.005079495662
#
#
# Product_ID
# square
# Adjusted R-Squared: 0.15554454047153388
# RMSE: 4622.959654877621
# sqrt
# Adjusted R-Squared: 0.15451850416112956
# RMSE: 4632.910849402497
# log
# Adjusted R-Squared: 0.15236213634034534
# RMSE: 4616.764179845474
#
#
# isMale
# square
# Adjusted R-Squared: 0.15477433135306085
# RMSE: 4624.636856344659
# sqrt
# Adjusted R-Squared: 0.15512531409911745
# RMSE: 4630.520850501174
# 0 in isMale, skipping
#
#
# Age
# square
# Adjusted R-Squared: 0.1550024456218423
# RMSE: 4619.503528578119
# sqrt
# Adjusted R-Squared: 0.15428821336986154
# RMSE: 4607.370622288014
# 0 in Age, skipping
#
#
# Occupation
# square
# Adjusted R-Squared: 0.15501827409376567
# RMSE: 4614.39829030758
# sqrt
# Adjusted R-Squared: 0.1556927919955211
# RMSE: 4625.317041747319
# 0 in Occupation, skipping
#
#
# City_Category
# square
# Adjusted R-Squared: 0.15502549769899066
# RMSE: 4611.684554673583
# sqrt
# Adjusted R-Squared: 0.15541150017940641
# RMSE: 4625.555077156921
# log
# Adjusted R-Squared: 0.15410935483825816
# RMSE: 4614.814156711151
#
#
# Marital_Status
# square
# Adjusted R-Squared: 0.15389983659368256
# RMSE: 4617.664699167141
# sqrt
# Adjusted R-Squared: 0.1541177987305924
# RMSE: 4610.96860312291
# 0 in Marital_Status, skipping
#
#
# Product_Category_1
# square
# Adjusted R-Squared: 0.1118763861789217
# RMSE: 4741.128878334782
# sqrt
# Adjusted R-Squared: 0.19585435844646126
# RMSE: 4492.361591132882
# log
# Adjusted R-Squared: 0.2372940138789036
# RMSE: 4390.018473823062
#
#
# Product_Category_2
# square
# Adjusted R-Squared: 0.15506072341343813
# RMSE: 4606.310931030888
# sqrt
# Adjusted R-Squared: 0.15537902227938605
# RMSE: 4617.053647830213
# 0 in Product_Category_2, skipping
#
#
# Product_Category_3
# square
# Adjusted R-Squared: 0.15151907946135001
# RMSE: 4631.976156599196
# sqrt
# Adjusted R-Squared: 0.15746924096123904
# RMSE: 4611.603396788221
# 0 in Product_Category_3, skipping

# %% [markdown]
# Certain transformations improve the RMSE, particularly log(Product_Category_1).

# %%
sorted(df.Purchase.unique(),reverse = True)
# Out:
# [23961,
#  23960,
#  23959,
#  23958,
#  23956,
#  23955,
#  23954,
#  23953,
#  23952,
#  23951,
#  23950,
#  23949,
#  23948,
#  23947,
#  23946,
#  23945,
#  23944,
#  23943,
#  23942,
#  23941,
#  23940,
#  23939,
#  23938,
#  23937,
#  23936,
#  23935,
#  23934,
#  23933,
#  23932,
#  23931,
#  23930,
#  23929,
#  23928,
#  23927,
#  23926,
#  23925,
#  23924,
#  23923,
#  23921,
#  23920,
#  23919,
#  23918,
#  23916,
#  23915,
#  23914,
#  23913,
#  23912,
#  23911,
#  23910,
#  23909,
#  23908,
#  23907,
#  23906,
#  23905,
#  23904,
#  23903,
#  23902,
#  23900,
#  23899,
#  23898,
#  23897,
#  23896,
#  23895,
#  23894,
#  23893,
#  23892,
#  23891,
#  23890,
#  23889,
#  23888,
#  23887,
#  23885,
#  23884,
#  23883,
#  23881,
#  23879,
#  23878,
#  23877,
#  23876,
#  23875,
#  23874,
#  23871,
#  23870,
#  23869,
#  23868,
#  23867,
#  23866,
#  23865,
#  23864,
#  23863,
#  23861,
#  23860,
#  23859,
#  23858,
#  23857,
#  23856,
#  23855,
#  23854,
#  23853,
#  23852,
#  23851,
#  23850,
#  23849,
#  23848,
#  23847,
#  23846,
#  23845,
#  23844,
#  23843,
#  23842,
#  23841,
#  23840,
#  23839,
#  23838,
#  23837,
#  23836,
#  23835,
#  23834,
#  23833,
#  23831,
#  23830,
#  23829,
#  23828,
#  23827,
#  23826,
#  23825,
#  23824,
#  23823,
#  23822,
#  23821,
#  23820,
#  23819,
#  23817,
#  23816,
#  23815,
#  23813,
#  23812,
#  23811,
#  23810,
#  23809,
#  23808,
#  23807,
#  23806,
#  23805,
#  23804,
#  23802,
#  23800,
#  23799,
#  23798,
#  23797,
#  23796,
#  23795,
#  23794,
#  23793,
#  23792,
#  23790,
#  23789,
#  23788,
#  23787,
#  23786,
#  23785,
#  23784,
#  23783,
#  23782,
#  23781,
#  23780,
#  23779,
#  23778,
#  23777,
#  23776,
#  23775,
#  23774,
#  23773,
#  23772,
#  23771,
#  23770,
#  23769,
#  23768,
#  23767,
#  23766,
#  23765,
#  23764,
#  23763,
#  23762,
#  23761,
#  23760,
#  23759,
#  23758,
#  23757,
#  23756,
#  23755,
#  23754,
#  23753,
#  23752,
#  23751,
#  23750,
#  23749,
#  23748,
#  23747,
#  23744,
#  23743,
#  23742,
#  23741,
#  23740,
#  23739,
#  23738,
#  23737,
#  23736,
#  23735,
#  23734,
#  23733,
#  23732,
#  23731,
#  23730,
#  23729,
#  23728,
#  23727,
#  23726,
#  23725,
#  23724,
#  23723,
#  23722,
#  23721,
#  23720,
#  23719,
#  23718,
#  23717,
#  23716,
#  23715,
#  23714,
#  23713,
#  23711,
#  23710,
#  23709,
#  23708,
#  23706,
#  23122,
#  23121,
#  23120,
#  23119,
#  23118,
#  23117,
#  23116,
#  23115,
#  23114,
#  23113,
#  23112,
#  23111,
#  23110,
#  23109,
#  23108,
#  23107,
#  23106,
#  23105,
#  23104,
#  23103,
#  23102,
#  23101,
#  23099,
#  23098,
#  23097,
#  23096,
#  23095,
#  23094,
#  23092,
#  23091,
#  23090,
#  23089,
#  23088,
#  23087,
#  23086,
#  23085,
#  23084,
#  23083,
#  23082,
#  23081,
#  23080,
#  23077,
#  23076,
#  23075,
#  23074,
#  23073,
#  23072,
#  23071,
#  23070,
#  23069,
#  23068,
#  23067,
#  23066,
#  23065,
#  23064,
#  23063,
#  23062,
#  23061,
#  23060,
#  23059,
#  23058,
#  23057,
#  23056,
#  23055,
#  23054,
#  23053,
#  23052,
#  23051,
#  23050,
#  23049,
#  23048,
#  23047,
#  23046,
#  23045,
#  23044,
#  23043,
#  23042,
#  23041,
#  23040,
#  23029,
#  23006,
#  22994,
#  22990,
#  22989,
#  22984,
#  22976,
#  22963,
#  22946,
#  22942,
#  22919,
#  22913,
#  22902,
#  22871,
#  22864,
#  22858,
#  22855,
#  22852,
#  22848,
#  22846,
#  22823,
#  22816,
#  22814,
#  22803,
#  22795,
#  22791,
#  22743,
#  22730,
#  22719,
#  22710,
#  22684,
#  22678,
#  22668,
#  22666,
#  22656,
#  22651,
#  21569,
#  21568,
#  21567,
#  21566,
#  21565,
#  21564,
#  21563,
#  21562,
#  21561,
#  21560,
#  21559,
#  21558,
#  21557,
#  21555,
#  21554,
#  21553,
#  21552,
#  21551,
#  21550,
#  21548,
#  21547,
#  21546,
#  21544,
#  21543,
#  21542,
#  21541,
#  21540,
#  21539,
#  21538,
#  21537,
#  21536,
#  21535,
#  21533,
#  21532,
#  21530,
#  21529,
#  21528,
#  21526,
#  21525,
#  21524,
#  21523,
#  21522,
#  21521,
#  21520,
#  21519,
#  21518,
#  21517,
#  21516,
#  21514,
#  21513,
#  21512,
#  21511,
#  21510,
#  21509,
#  21508,
#  21507,
#  21506,
#  21505,
#  21504,
#  21503,
#  21502,
#  21501,
#  21500,
#  21499,
#  21497,
#  21495,
#  21494,
#  21493,
#  21491,
#  21490,
#  21489,
#  21488,
#  21487,
#  21486,
#  21485,
#  21484,
#  21482,
#  21481,
#  21479,
#  21478,
#  21477,
#  21476,
#  21475,
#  21474,
#  21472,
#  21471,
#  21470,
#  21469,
#  21468,
#  21467,
#  21466,
#  21464,
#  21463,
#  21462,
#  21461,
#  21459,
#  21456,
#  21455,
#  21454,
#  21453,
#  21452,
#  21451,
#  21450,
#  21449,
#  21448,
#  21447,
#  21446,
#  21445,
#  21444,
#  21443,
#  21442,
#  21441,
#  21440,
#  21439,
#  21438,
#  21437,
#  21436,
#  ...]

# %%
import diagnostic_plots

# %%
tempSlice = train.sample(n=1000)
X = tempSlice.drop(['Purchase','Stay_In_Current_City_Years'],axis=1)
y = tempSlice.Purchase
simple_model = sm.OLS(y,sm.add_constant(X)).fit()
diagnostic_plots.diagnostic_plots(X,y,model_fit=simple_model)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-721c0125813a> in <module>()
#       3 y = tempSlice.Purchase
#       4 simple_model = sm.OLS(y,sm.add_constant(X)).fit()
# ----> 5 diagnostic_plots.diagnostic_plots(X,y,model_fit=simple_model)
#
# ~/Documents/MSIS_2631/Project/notebooks/diagnostic_plots.py in diagnostic_plots(X, y, model_fit, fit_intercept)
#     137     for i in abs_norm_resid_top_3:
#     138         plot_lm_3.axes[0].annotate(i,
# --> 139                                     xy=(model_fitted_y[i],
#     140                                         model_norm_residuals_abs_sqrt[i]));
#     141
#
# /usr/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# /usr/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 207

# %%
X.iloc[62]
# Out:
# User_ID               1002259
# Product_ID             289942
# isMale                      0
# Age                         6
# Occupation                 16
# City_Category               3
# Marital_Status              1
# Product_Category_1          3
# Product_Category_2          4
# Product_Category_3          5
# Name: 482611, dtype: int64

# %%
freq = np.unique(train.Purchase,return_counts = True)[1]
unique = np.unique(train.Purchase,return_counts = True)[0]

# %%
plt.figure(figsize=(23,7))
plt.scatter(unique,freq)
plt.plot()
# Out:
# []

# %%
lasso_model = LassoCV(alphas=np.logspace(-4,0,100),normalize=True,max_iter=100000,cv=5)
X = train.drop(columns=['Purchase','Stay_In_Current_City_Years'],axis=1)
y = train.Purchase

# %%
lasso_model.fit(X,y)
# Out:
# LassoCV(alphas=array([1.00000e-04, 1.09750e-04, ..., 9.11163e-01, 1.00000e+00]),
#     copy_X=True, cv=5, eps=0.001, fit_intercept=True, max_iter=100000,
#     n_alphas=100, n_jobs=None, normalize=True, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=False)

# %%
lasso_predict = lasso_model.predict(test.drop(['Purchase','Stay_In_Current_City_Years'],axis=1))

# %%
print(rmse(lasso_predict,test.Purchase))
# Out:
# 4615.249565158195

# %%
ridge_model = RidgeCV(alphas=np.logspace(-5,0,100),normalize=True)

# %%
ridge_model.fit(X,y)
ridge_predict = ridge_model.predict(test.drop(['Purchase','Stay_In_Current_City_Years'],axis=1))

# %%
print(rmse(ridge_predict,test.Purchase))
# Out:
# 4615.250948517098

# %%
df.Purchase.mean()
# Out:
# 9263.968712959126

# %% [markdown]
# As per professor's suggestion, split on Purchase = 15000 (It's not exactly 15000, but close enough)

# %%
dfLow = df[(df.Purchase <= 15000)]
dfHigh = df[(df.Purchase > 15000)]

# %%
trainLow, testLow = train_test_split(dfLow,test_size=0.3)

# %%
Xlow = trainLow.drop(['Purchase','Stay_In_Current_City_Years'],axis=1)
yLow = trainLow.Purchase

# %%
multivar_model = sm.OLS(yLow,sm.add_constant(Xlow)).fit()

# %%
predict = multivar_model.predict(sm.add_constant(testLow.drop(['Purchase','Stay_In_Current_City_Years'],axis=1)))
print(rmse(predict,testLow.Purchase))
# Out:
# 2856.1522606388053

# %%
multivar_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Purchase   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     5288.
# Date:                Fri, 30 Nov 2018   Prob (F-statistic):               0.00
# Time:                        11:58:51   Log-Likelihood:            -2.8867e+06
# No. Observations:              307681   AIC:                         5.773e+06
# Df Residuals:                  307670   BIC:                         5.773e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               8862.2262   3010.522      2.944      0.003    2961.688    1.48e+04
# User_ID               -0.0004      0.003     -0.127      0.899      -0.006       0.006
# Product_ID            -0.0010   5.07e-05    -18.936      0.000      -0.001      -0.001
# isMale                86.3624     11.910      7.251      0.000      63.018     109.707
# Age                  102.1504      4.077     25.056      0.000      94.160     110.141
# Occupation             1.1730      0.801      1.465      0.143      -0.397       2.743
# City_Category        114.2234      6.883     16.595      0.000     100.733     127.714
# Marital_Status       -17.3364     11.090     -1.563      0.118     -39.072       4.399
# Product_Category_1  -290.6081      1.515   -191.789      0.000    -293.578    -287.638
# Product_Category_2   -10.3273      0.832    -12.412      0.000     -11.958      -8.696
# Product_Category_3    46.0334      0.965     47.699      0.000      44.142      47.925
# ==============================================================================
# Omnibus:                      181.521   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              179.590
# Skew:                           0.052   Prob(JB):                     1.01e-39
# Kurtosis:                       2.945   Cond. No.                     5.92e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.92e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
trainHigh, testHigh = train_test_split(dfHigh,test_size=0.3)

# %%
Xhigh = trainHigh.drop(['Purchase','Stay_In_Current_City_Years'],axis=1)
yHigh = trainHigh.Purchase

# %%
multivar_model_high = sm.OLS(yHigh,sm.add_constant(Xhigh)).fit()

# %%
predict = multivar_model_high.predict(sm.add_constant(testHigh.drop(['Purchase','Stay_In_Current_City_Years'],axis=1)))
print(rmse(predict,testHigh.Purchase))
# Out:
# 1958.2960207241242

# %%
multivar_model_high.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Purchase   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     1171.
# Date:                Fri, 30 Nov 2018   Prob (F-statistic):               0.00
# Time:                        12:12:45   Log-Likelihood:            -6.9691e+05
# No. Observations:               77366   AIC:                         1.394e+06
# Df Residuals:                   77355   BIC:                         1.394e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1.664e+04   4135.842      4.024      0.000    8534.728    2.47e+04
# User_ID                0.0002      0.004      0.041      0.967      -0.008       0.008
# Product_ID            -0.0028   7.39e-05    -37.721      0.000      -0.003      -0.003
# isMale                 9.9662     18.148      0.549      0.583     -25.604      45.536
# Age                    8.6520      5.608      1.543      0.123      -2.339      19.643
# Occupation            -1.9778      1.118     -1.769      0.077      -4.169       0.213
# City_Category         82.0507      9.408      8.721      0.000      63.611     100.490
# Marital_Status       -14.3903     15.201     -0.947      0.344     -44.183      15.403
# Product_Category_1   166.9057      1.750     95.356      0.000     163.475     170.336
# Product_Category_2    34.6354      1.235     28.037      0.000      32.214      37.057
# Product_Category_3     4.6359      1.097      4.225      0.000       2.485       6.786
# ==============================================================================
# Omnibus:                    52586.371   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7674.032
# Skew:                           0.507   Prob(JB):                         0.00
# Kurtosis:                       1.838   Cond. No.                     5.91e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.91e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Using the guide from https://plot.ly/ipython-notebooks/principal-component-analysis/ for PCA to tackle possible multicollinearity

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_std = StandardScaler().fit_transform(Xhigh)
# Out:
# /usr/lib/python3.7/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
print('NumPy covariance matrix: \n%s' %np.cov(X_std.T))
# Out:
# NumPy covariance matrix:
# [[ 1.00001293e+00 -9.95119018e-03 -5.12643434e-02  2.41158831e-02
#   -1.12571036e-02  2.47655755e-02  4.87379468e-03  7.76322944e-03
#   -7.04799902e-04 -5.54113381e-03]
#  [-9.95119018e-03  1.00001293e+00  1.20879293e-02  2.51121690e-02
#    9.87654933e-03 -1.22752707e-02  8.09814982e-03  5.08376823e-02
#   -2.14794377e-02 -1.79794379e-01]
#  [-5.12643434e-02  1.20879293e-02  1.00001293e+00 -2.53965940e-02
#    1.08375123e-01  1.00386889e-02 -2.47377378e-02 -4.20883032e-02
#    2.87146628e-02  1.32619564e-02]
#  [ 2.41158831e-02  2.51121690e-02 -2.53965940e-02  1.00001293e+00
#    1.02496481e-01  1.17402909e-01  3.05070732e-01  5.04365691e-02
#   -4.35376969e-03 -3.22739099e-03]
